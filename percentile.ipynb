# %% [markdown]
# <a href="https://colab.research.google.com/github/Nivrutti-Chavan/Machine_Learning/blob/main/percentile.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("weight-height.csv")

# %%
df.sample(10)
# Out:
#       Gender     Height      Weight
# 5686  Female  62.573492  120.583445
# 4495    Male  65.594613  162.291597
# 3638    Male  66.822744  189.236104
# 957     Male  69.031063  170.310122
# 827     Male  68.694210  179.962509
# 1370    Male  65.854205  178.031460
# 9164  Female  64.430933  130.277479
# 6470  Female  65.804847  156.362511
# 274     Male  67.565040  187.187094
# 1362    Male  67.413152  168.634975

# %%
df["Height"].describe()
# Out:
# count    10000.000000
# mean        66.367560
# std          3.847528
# min         54.263133
# 25%         63.505620
# 50%         66.318070
# 75%         69.174262
# max         78.998742
# Name: Height, dtype: float64

# %%
sns.displot(df["Height"])

# %%
sns.boxplot(df["Height"])
# Out:
# <Axes: ylabel='Height'>

# %%
upper_limit=df["Height"].quantile(0.99)
lower_limit=df["Height"].quantile(0.01)
print(upper_limit)
print(lowe_limit)
# Out:
# 74.7857900583366
# 58.13441158671655

# %%
df[(df["Height"]>74.78) | (df["Height"]<58.13)]
# Out:
#       Gender     Height      Weight
# 23      Male  75.205974  228.761781
# 190     Male  76.709835  235.035419
# 197     Male  75.944460  231.924749
# 202     Male  75.140821  224.124271
# 215     Male  74.795375  232.635403
# ...      ...        ...         ...
# 9761  Female  56.975279   90.341784
# 9825  Female  55.979198   85.417534
# 9895  Female  57.740192   93.652957
# 9904  Female  57.028857  101.202551
# 9978  Female  57.375759  114.192209
#
# [201 rows x 3 columns]

# %%
new_df=df[(df["Height"]<=74.78) & (df["Height"]>=58.13)]
new_df.shape
# Out:
# (9799, 3)

# %%
sns.boxplot(new_df["Height"])
# Out:
# <Axes: ylabel='Height'>

# %%
#Capping--->>>>Winsorization
df["new_df_cap"]=new_df_cap=np.where(
    df["Height"]>=upper_limit,
    upper_limit,
    np.where(
        df["Height"]<= lower_limit,
        lower_limit,
        df["Height"]
    )

)

# %%
df["new_df_cap"].describe()
# Out:
# count    10000.000000
# mean        66.366281
# std          3.795717
# min         58.134412
# 25%         63.505620
# 50%         66.318070
# 75%         69.174262
# max         74.785790
# Name: new_df_cap, dtype: float64
