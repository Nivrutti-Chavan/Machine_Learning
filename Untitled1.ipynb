# %% [markdown]
# <a href="https://colab.research.google.com/github/Nivrutti-Chavan/Machine_Learning/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df=pd.read_json("https://jsonplaceholder.typicode.com/users")
