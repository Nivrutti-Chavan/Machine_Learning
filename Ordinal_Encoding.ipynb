# %%
import pandas as pd

# %%
df=pd.read_csv("customer.csv")
df.head(5)
# Out:
#    age  gender   review education purchased
# 0   30  Female  Average    School        No
# 1   68  Female     Poor        UG        No
# 2   70  Female     Good        PG        No
# 3   72  Female     Good        PG        No
# 4   16  Female  Average        UG        No

# %% [markdown]
# # Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()
df["gender"]=le.fit_transform(df["gender"])
df.sample(5)

# %%
df["purchased"]=le.fit_transform(df["purchased"])
df["gender"]=le.fit_transform(df["gender"])
df.head(5)

# %% [markdown]
# #Ordinal_Encoding

# %%
from sklearn.preprocessing import OrdinalEncoder
encoder=OrdinalEncoder()

df=pd.DataFrame({
    "review":["Poor","Average","Good"],
    "education":["School","UG","PG"]
})

encoder=OrdinalEncoder(
    categories=[
        ["Poor","Average","Good"],
        ["School","UG","PG"]
    ]
)


df[['Review_encoded','Education_Encoded']] = encoder.fit_transform(df[['review','education']])

df.head()
print(df)
# Out:
#     review education  Review_encoded  Education_Encoded
# 0     Poor    School             0.0                0.0
# 1  Average        UG             1.0                1.0
# 2     Good        PG             2.0                2.0

# %%
"""
| Feature          | Label Encoding                | Ordinal Encoding     |
| ---------------- | ----------------------------- | -------------------- |
| Used for         | Categories/labels             | Ordered categories   |
| Order important? | ❌ No                          | ✅ Yes                |
| Example          | Male, Female                  | Low, Medium, High    |
| Encoding         | Automatically assigns numbers | You define the order |
| Sklearn class    | `LabelEncoder()`              | `OrdinalEncoder()`   |


"""
